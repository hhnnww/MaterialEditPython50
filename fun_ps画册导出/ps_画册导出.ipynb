# %%
from win32com.client import Dispatch

app = Dispatch("photoshop.application")

# %%
app.Open(r"F:\小夕素材\10000-20000\10873\10873\小夕素材(1).psd")
# Out:
# <COMObject Open>

# %%
dir(app)
# Out:
# ['ActiveDocument',
#  'Application',
#  'BackgroundColor',
#  'Batch',
#  'Build',
#  'ChangeColorSettings',
#  'CharIDToTypeID',
#  'ColorSettings',
#  'CurrentTool',
#  'DisplayDialogs',
#  'DoAction',
#  'DoJavaScript',
#  'DoJavaScriptFile',
#  'Documents',
#  'ExecuteAction',
#  'ExecuteActionGet',
#  'FeatureEnabled',
#  'Fonts',
#  'ForegroundColor',
#  'FreeMemory',
#  'Load',
#  'Locale',
#  'MacintoshFileTypes',
#  'MakeContactSheet',
#  'MakePDFPresentation',
#  'MakePhotoGallery',
#  'MakePhotomerge',
#  'MakePicturePackage',
#  'MeasurementLog',
#  'Name',
#  'Notifiers',
#  'NotifiersEnabled',
#  'Open',
#  'OpenDialog',
#  'Path',
#  'Preferences',
#  'PreferencesFolder',
#  'Purge',
#  'Quit',
#  'RecentFiles',
#  'Refresh',
#  'ScriptingBuildDate',
#  'ScriptingVersion',
#  'StringIDToTypeID',
#  'SystemInformation',
#  'TypeIDToCharID',
#  'TypeIDToStringID',
#  'Version',
#  'Visible',
#  'WinColorSettings',
#  'WindowsFileTypes',
#  '_ApplyTypes_',
# ...

# %%
doc = app.ActiveDocument
dir(doc)
# Out:
# ['ActiveChannels',
#  'ActiveHistoryBrushSource',
#  'ActiveHistoryState',
#  'ActiveLayer',
#  'Application',
#  'ArtLayers',
#  'AutoCount',
#  'BackgroundLayer',
#  'BitsPerChannel',
#  'ChangeMode',
#  'Channels',
#  'Close',
#  'ColorProfileName',
#  'ColorProfileType',
#  'ColorSamplers',
#  'ComponentChannels',
#  'ConvertProfile',
#  'CountItems',
#  'Crop',
#  'Duplicate',
#  'Export',
#  'Flatten',
#  'FlipCanvas',
#  'FullName',
#  'Height',
#  'Histogram',
#  'HistoryStates',
#  'ImportAnnotations',
#  'Info',
#  'LayerComps',
#  'LayerSets',
#  'Layers',
#  'Managed',
#  'MeasurementScale',
#  'MergeVisibleLayers',
#  'Mode',
#  'Name',
#  'Parent',
#  'Paste',
#  'Path',
#  'PathItems',
#  'PixelAspectRatio',
#  'PrintOut',
#  'QuickMaskMode',
#  'RasterizeAllLayers',
#  'RecordMeasurements',
#  'ResizeCanvas',
#  'ResizeImage',
#  'Resolution',
#  'RevealAll',
#  'RotateCanvas',
#  'Save',
#  'SaveAs',
#  'Saved',
#  'Selection',
#  'SplitChannels',
#  'Trap',
# ...

# %%
dir(doc.BackgroundLayer)
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dir(doc.BackgroundLayer)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\win32com\client\dynamic.py:628, in CDispatch.__getattr__(self, attr)
#     624 debug_attr_print(
#     625     "Getting property Id 0x%x from OLE object" % retEntry.dispid
#     626 )
#     627 try:
# --> 628     ret = self._oleobj_.Invoke(retEntry.dispid, 0, invoke_type, 1)
#     629 except pythoncom.com_error as details:
#     630     if details.hresult in ERRORS_BAD_CONTEXT:
#     631         # May be a method.
#
# com_error: (-2147352567, '发生意外。', (0, 'Adobe Photoshop', '没有这种元素', None, 0, -2147352565), None)
