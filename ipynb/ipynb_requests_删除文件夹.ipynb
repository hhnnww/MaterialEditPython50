# %%
from requests_html import HTMLSession

# %%
maid_list = [
    "10088",
    "10087",
    "H0683",
    "H0668",
    "H0667",
    "H0666",
    "H0665",
    "10081",
    "H0656",
    "H0657",
    "H0650",
    "9226",
    "会员VIP",
    "1886",
    "4552",
]

for maid in maid_list:
    print(maid)
    if "H" not in maid:
        ma_path = f'["/10000-10999/{maid}"]'
    else:
        ma_path = f'["/H000-H999/{maid}"]'

    url = "https://pan.baidu.com/api/filemanager?async=2&onnest=fail&opera=delete&bdstoken=a2688f8e900b2516abcf6013bba3377b&newVerify=1&clienttype=0&app_id=250528&web=1&dp-logid=31948900918580790054"
    session = HTMLSession()

    res = session.post(
        url,
        data={"filelist": ma_path},
        headers={
            "Accept": "application/json, text/plain, */*",
            "Accept-Encoding": "gzip, deflate, br, zstd",
            "Accept-Language": "zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6",
            "Connection": "keep-alive",
            "Content-Length": "43",
            "Content-Type": "application/x-www-form-urlencoded",
            "Cookie": "PANWEB=1; BIDUPSID=AD7C185360DF7161E2F9A633B11CDDDE; PSTM=1693662186; ZFY=SE8d6iJAEw0RplWClwwyUNjtdqQUVicD8AkqLdNHZjs:C; BAIDUID=AD7C185360DF7161E2F9A633B11CDDDE:SL=0:NR=10:FG=1; BAIDUID_BFESS=AD7C185360DF7161E2F9A633B11CDDDE:SL=0:NR=10:FG=1; Hm_lvt_fa0277816200010a74ab7d2895df481b=1699071411; Hm_lvt_0ba7bcf57b5e55fbfbab9a2750acdf3e=1704076593; H_WISE_SIDS=283702_284830_287047_110085_282466_283016_287627_280167_288271_287981_281879_284816_289236_288153_289948_282929_290204_271560_290394_290448_290358_290555_290560_290562_282805_291049_290976_291154_287174_291189_287238_286864; H_WISE_SIDS_BFESS=283702_284830_287047_110085_282466_283016_287627_280167_288271_287981_281879_284816_289236_288153_289948_282929_290204_271560_290394_290448_290358_290555_290560_290562_282805_291049_290976_291154_287174_291189_287238_286864; __bid_n=18cfbc4a30a5072f92495a; BDUSS=npIS2NvbkttZERaM0dVMjFlbW1ERTRUMWtLUXhKbVhHTGxNU21LUkZacndnQzltSVFBQUFBJCQAAAAAAQAAAAEAAAAA~5YOAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAPDzB2bw8wdmT; BDUSS_BFESS=npIS2NvbkttZERaM0dVMjFlbW1ERTRUMWtLUXhKbVhHTGxNU21LUkZacndnQzltSVFBQUFBJCQAAAAAAQAAAAEAAAAA~5YOAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAPDzB2bw8wdmT; H_PS_PSSID=40373_40369_40416_40446_40302_40465_40459_40506_40514_40398_60024_60038_60047_40511_60087; BDCLND=tAgZtCb%2BQB2IGPpbz%2F7js6him1rkJJoSdeSO5fr2ids%3D; Hm_lvt_7a3960b6f067eb0085b7f96ff5e660b0=1712555480,1712657911,1714108532,1714455171; STOKEN=fcfcc5f28e1363a94b3b63005e6f9b887eeab19b87ecd654be3f1285664df46d; newlogin=1; MCITY=-218%3A; csrfToken=-futk3d92jNx9v9il3_RWNgZ; PANPSC=15210568941116385994%3AKkwrx6t0uHCOaq2AHCOWtCnGttqtUqs9joifqifyct4HudbJ5vc44CvbCphtI0nMZ7VPoRKOoyFcdBzhprT8skTY6Utkim9aEFB3kkm1IYU%2Bb5dP6NpttXLHifXOvYgnkL2qAeJq7%2BVrtVfl9ibEZ%2BItotSXQoPkpbLROUj5lBWM7K5cBlVvmAEMKGmQS2qL; ndut_fmt=884F18F3B78A36B320614B57574257C4BA6857F7D271EF120B94BE168DA34386; ab_sr=1.0.1_",
            "Host": "pan.baidu.com",
            "Origin": "https://pan.baidu.com",
            "Referer": "https://pan.baidu.com/disk/main",
            "Sec-Fetch-Dest": "empty",
            "Sec-Fetch-Mode": "cors",
            "Sec-Fetch-Site": "same-origin",
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36 Edg/125.0.0.0",
            "X-Requested-With": "XMLHttpRequest",
            "sec-ch-ua": '"Microsoft Edge";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
            "sec-ch-ua-mobile": "?0",
            "sec-ch-ua-platform": '"Windows"',
        },
    )

    print(res.json(), "\n\n")
# Out:
# 10088
# {'errno': 0, 'info': [], 'request_id': 8812798412669800553, 'taskid': 910573377776844}
#
#
# 10087
# {'errno': 12, 'info': [{'errno': 111, 'path': '/10000-10999/10087'}], 'request_id': 8812798654890548018}
#
#
# H0683
# {'errno': 0, 'info': [], 'request_id': 8812798811301438166, 'taskid': 853535104350398}
#
#
# H0668
# {'errno': 12, 'info': [{'errno': 111, 'path': '/H000-H999/H0668'}], 'request_id': 8812799025937552230}
#
#
# H0667
# {'errno': 0, 'info': [], 'request_id': 8812799318479052519, 'taskid': 873626604940998}
#
#
# H0666
# {'errno': 12, 'info': [{'errno': 111, 'path': '/H000-H999/H0666'}], 'request_id': 8812799478115343227}
#
#
# H0665
# {'errno': 0, 'info': [], 'request_id': 8812799623537780396, 'taskid': 477022749778297}
#
#
# 10081
# {'errno': 0, 'info': [], 'request_id': 8812800370646189201, 'taskid': 489888766570140}
#
#
# H0656
# {'errno': 12, 'info': [{'errno': 111, 'path': '/H000-H999/H0656'}], 'request_id': 8812800647432663529}
#
#
# H0657
# ...
