# %%
from selenium.webdriver import Edge, EdgeOptions
from selenium.webdriver.common.by import By

from MaterialEdit.fun_素材下载.fun_插入素材 import fun_插入素材
from MaterialEdit.fun_素材下载.model_素材格式 import MaterialModel

options = EdgeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-gpu")
options.add_argument("--remote-debugging-port=9222")
options.add_argument("--single-process")

driver = Edge(options=options)
driver.implicitly_wait(50)
driver.set_window_rect(x=1274, y=0, width=1292, height=1398)
# Out:
# The msedgedriver version (128.0.2739.67) detected in PATH at C:\Program Files\edgedriver_win64\msedgedriver.exe might not be compatible with the detected MicrosoftEdge version (129.0.2792.89); currently, msedgedriver 129.0.2792.89 is recommended for MicrosoftEdge 129.*, so it is advised to delete the driver in PATH and retry
# {'height': 1398, 'width': 1292, 'x': 1274, 'y': 0}

# %%
while True:
    driver.get(
        "https://shop422531534.taobao.com/search.htm?spm=a1z10.3-c.w4002-18811532825.9.52146de49ZLsNa&_ksTS=1729253644167_326&callback=jsonp327&input_charset=gbk&mid=w-18811532825-0&wid=18811532825&path=%2Fsearch.htm&search=y&orderType=hotsell_desc&pageNo=19"
    )

    objs = driver.find_elements(
        by=By.CSS_SELECTOR,
        value="#J_ShopSearchResult > div > div.shop-hesper-bd.grid > div > dl > dt > a",
    )

    for obj in objs:
        url = obj.get_dom_attribute("href")
        if "https:" not in url:
            url = "https:" + url

        img = "https:" + obj.find_element(By.CSS_SELECTOR, "img").get_dom_attribute(
            "src"
        ).replace("_240x240.jpg", "")

        print(url, img)
        obj_mod = MaterialModel(url=url, img=img, state=False)
        fun_插入素材(
            shop_name="泡泡素材", material_site="青青草素材王国", material_model=obj_mod
        )

    driver.find_element(
        By.CSS_SELECTOR,
        "#J_ShopSearchResult > div > div.shop-hesper-bd.grid > div.shop-filter > div.pagination.pagination-mini > a:nth-child(3)",
    ).click()
# Out:
# https://item.taobao.com/item.htm?id=818255600382 https://img.alicdn.com/bao/uploaded/i4/3700963838/O1CN01dZ3E0K1eDr4gmwHpp_!!3700963838.jpg
# 插入到数据库：6712532d55c580040540da65
# https://item.taobao.com/item.htm?id=825475945139 https://img.alicdn.com/bao/uploaded/i3/3700963838/O1CN01cp1hwc1eDr5C42OYW_!!3700963838.jpg
# 插入到数据库：6712532d55c580040540da66
# https://item.taobao.com/item.htm?id=827278285992 https://img.alicdn.com/bao/uploaded/i3/3700963838/O1CN01Il4dAK1eDr5Fd8ryq_!!3700963838.jpg
# 插入到数据库：6712532d55c580040540da67
# https://item.taobao.com/item.htm?id=835275045929 https://img.alicdn.com/bao/uploaded/i4/3700963838/O1CN01fPjqhM1eDr5iWSRvc_!!3700963838.jpg
# 插入到数据库：6712532d55c580040540da68
# https://item.taobao.com/item.htm?id=837520095787 https://img.alicdn.com/bao/uploaded/i3/3700963838/O1CN01WnihL61eDr5spu33h_!!3700963838.jpg
# 插入到数据库：6712532d55c580040540da69
# ...
