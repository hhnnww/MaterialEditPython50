# %%
"""
直接去电商宝复制请求标头
然后开始自动采集订单
"""

import re

import pyperclip
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from requests_html import HTMLSession

session = HTMLSession()

# 构建数据库
uri = "mongodb://192.168.0.110:27017/"
client = MongoClient(uri, server_api=ServerApi("1"))
database = client["电商宝返款订单"]
collect = database["订单列表"]

# 获取请求标头
req_header = pyperclip.paste().strip()

# 构建所有url列表
req_split = req_header.split("\n")
url: str = "https://appscrm.ecbao.cn" + re.findall(r"\s(.*?)\s", req_split[0])[0]
all_url = []
for x in range(1, 10000):
    new_url = url.replace("page=1", f"page={x}")
    all_url.append(new_url)

# 构建请求标头
header_dict = {}
for req_line in req_split[1:]:
    req_line = req_line.strip()
    line_split = req_line.split(": ")
    header_dict.update({line_split[0]: line_split[1]})

can_scrapy = True
for num, url in enumerate(all_url):
    if can_scrapy is True:
        print(f"开始采集第{num+1}页:{url}")

        with session.post(url, headers=header_dict) as res:
            objs = res.json().get("data").get("data")

            for obj in objs:
                order_sn = obj.get("order_sn")
                count = collect.count_documents(
                    filter={"order_sn": obj.get("order_sn")}
                )
                if count == 0:
                    insert_res = collect.insert_one(obj)
                    print(
                        f'插入数据：{insert_res.inserted_id}\nwechat:{obj.get("wechat_nick")}'
                    )

                else:
                    print("数据存在")
                    can_scrapy = False
                    break
# Out:
# 开始采集第1页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=1&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a7feb3bb745ece5e7fc
# wechat:yoko
# 插入数据：67186a7feb3bb745ece5e7fd
# wechat:NG Studio_小灌
# 插入数据：67186a80eb3bb745ece5e7fe
# wechat:醉世魔王
# 插入数据：67186a80eb3bb745ece5e7ff
# wechat:NG Studio_小灌
# 插入数据：67186a80eb3bb745ece5e800
# wechat:NG Studio_小灌
# 插入数据：67186a80eb3bb745ece5e801
# wechat:蒋阳
# 插入数据：67186a80eb3bb745ece5e802
# wechat:伤心小土豆
# 插入数据：67186a80eb3bb745ece5e803
# wechat:伤心小土豆
# 插入数据：67186a80eb3bb745ece5e804
# wechat:丶 与yi同心
# 插入数据：67186a80eb3bb745ece5e805
# wechat:初梦
# 插入数据：67186a80eb3bb745ece5e806
# wechat:初梦
# 插入数据：67186a80eb3bb745ece5e807
# wechat:初梦
# 插入数据：67186a80eb3bb745ece5e808
# wechat:anle
# 插入数据：67186a80eb3bb745ece5e809
# wechat:Candy
# 插入数据：67186a80eb3bb745ece5e80a
# wechat:木槿
# 插入数据：67186a80eb3bb745ece5e80b
# wechat:小潘
# 插入数据：67186a80eb3bb745ece5e80c
# wechat:立早
# 插入数据：67186a80eb3bb745ece5e80d
# wechat:张洁
# 插入数据：67186a80eb3bb745ece5e80e
# wechat:啊噢
# 插入数据：67186a80eb3bb745ece5e80f
# wechat:张歪歪
# 开始采集第2页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=2&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a81eb3bb745ece5e810
# wechat:张歪歪
# 插入数据：67186a81eb3bb745ece5e811
# wechat:Nuo.
# 插入数据：67186a81eb3bb745ece5e812
# wechat:Nuo.
# 插入数据：67186a81eb3bb745ece5e813
# wechat:Nuo.
# 插入数据：67186a81eb3bb745ece5e814
# wechat:Solitude
# 插入数据：67186a81eb3bb745ece5e815
# wechat:Solitude
# 插入数据：67186a81eb3bb745ece5e816
# wechat:Solitude
# 插入数据：67186a81eb3bb745ece5e817
# wechat:KIMI
# 插入数据：67186a81eb3bb745ece5e818
# wechat:yoongi
# 插入数据：67186a81eb3bb745ece5e819
# wechat:Isabella
# 插入数据：67186a81eb3bb745ece5e81a
# wechat:不负如来不负卿
# 插入数据：67186a81eb3bb745ece5e81b
# wechat:s
# 插入数据：67186a81eb3bb745ece5e81c
# wechat:s
# 插入数据：67186a81eb3bb745ece5e81d
# wechat:s
# 插入数据：67186a81eb3bb745ece5e81e
# wechat:猫猫吃云朵
# 插入数据：67186a82eb3bb745ece5e81f
# wechat:s
# 插入数据：67186a82eb3bb745ece5e820
# wechat:猫猫吃云朵
# 插入数据：67186a82eb3bb745ece5e821
# wechat:Ting
# 插入数据：67186a82eb3bb745ece5e822
# wechat:
# 插入数据：67186a82eb3bb745ece5e823
# wechat:晴天，晴天
# 开始采集第3页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=3&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a82eb3bb745ece5e824
# wechat:Caiy
# 插入数据：67186a82eb3bb745ece5e825
# wechat:清净
# 插入数据：67186a82eb3bb745ece5e826
# wechat:清净
# 插入数据：67186a82eb3bb745ece5e827
# wechat:吃肉的兔子
# 插入数据：67186a82eb3bb745ece5e828
# wechat:馆长-室内博物馆
# 插入数据：67186a82eb3bb745ece5e829
# wechat:kuaile
# 插入数据：67186a82eb3bb745ece5e82a
# wechat:微信用户
# 插入数据：67186a82eb3bb745ece5e82b
# wechat:恭喜
# 插入数据：67186a82eb3bb745ece5e82c
# wechat:路
# 插入数据：67186a82eb3bb745ece5e82d
# wechat:路
# 插入数据：67186a82eb3bb745ece5e82e
# wechat:白猫很黑-任艺
# 插入数据：67186a83eb3bb745ece5e82f
# wechat:张大哈哈
# 插入数据：67186a83eb3bb745ece5e830
# wechat:张大哈哈
# 插入数据：67186a83eb3bb745ece5e831
# wechat:Mo Tang
# 插入数据：67186a83eb3bb745ece5e832
# wechat:
# 插入数据：67186a83eb3bb745ece5e833
# wechat:
# 插入数据：67186a83eb3bb745ece5e834
# wechat:@123
# 插入数据：67186a83eb3bb745ece5e835
# wechat:@123
# 插入数据：67186a83eb3bb745ece5e836
# wechat:@123
# 插入数据：67186a83eb3bb745ece5e837
# wechat:非鱼
# 开始采集第4页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=4&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a83eb3bb745ece5e838
# wechat:阳琼
# 插入数据：67186a83eb3bb745ece5e839
# wechat:A3
# 插入数据：67186a83eb3bb745ece5e83a
# wechat:王逗逗
# 插入数据：67186a83eb3bb745ece5e83b
# wechat:王逗逗
# 插入数据：67186a83eb3bb745ece5e83c
# wechat:王逗逗
# 插入数据：67186a83eb3bb745ece5e83d
# wechat:Ethereal
# 插入数据：67186a84eb3bb745ece5e83e
# wechat:自渡
# 插入数据：67186a84eb3bb745ece5e83f
# wechat:划啊滑
# 插入数据：67186a84eb3bb745ece5e840
# wechat:胡志明
# 插入数据：67186a84eb3bb745ece5e841
# wechat:Nancy
# 插入数据：67186a84eb3bb745ece5e842
# wechat:啊
# 插入数据：67186a84eb3bb745ece5e843
# wechat:啊
# 插入数据：67186a84eb3bb745ece5e844
# wechat:啊
# 插入数据：67186a84eb3bb745ece5e845
# wechat:啊
# 插入数据：67186a84eb3bb745ece5e846
# wechat:许·小凡、
# 插入数据：67186a84eb3bb745ece5e847
# wechat:哄哄
# 插入数据：67186a84eb3bb745ece5e848
# wechat:
# 插入数据：67186a84eb3bb745ece5e849
# wechat:慢慢
# 插入数据：67186a84eb3bb745ece5e84a
# wechat:Pipi
# 插入数据：67186a84eb3bb745ece5e84b
# wechat:雨淅
# 开始采集第5页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=5&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a85eb3bb745ece5e84c
# wechat:雨淅
# 插入数据：67186a85eb3bb745ece5e84d
# wechat:菲菲
# 插入数据：67186a85eb3bb745ece5e84e
# wechat:微信用户
# 插入数据：67186a85eb3bb745ece5e84f
# wechat:YhaN
# 插入数据：67186a85eb3bb745ece5e850
# wechat:yǔ
# 插入数据：67186a85eb3bb745ece5e851
# wechat:顺哥
# 插入数据：67186a85eb3bb745ece5e852
# wechat:LILI
# 插入数据：67186a85eb3bb745ece5e853
# wechat:顺哥
# 插入数据：67186a85eb3bb745ece5e854
# wechat:L
# 插入数据：67186a85eb3bb745ece5e855
# wechat:L
# 插入数据：67186a85eb3bb745ece5e856
# wechat:nice
# 插入数据：67186a85eb3bb745ece5e857
# wechat:nice
# 插入数据：67186a86eb3bb745ece5e858
# wechat:Yamisasawu
# 插入数据：67186a86eb3bb745ece5e859
# wechat:伯言
# 插入数据：67186a86eb3bb745ece5e85a
# wechat:对方正在长头发
# 插入数据：67186a86eb3bb745ece5e85b
# wechat:对方正在长头发
# 插入数据：67186a86eb3bb745ece5e85c
# wechat:阿轩
# 插入数据：67186a86eb3bb745ece5e85d
# wechat:
# 插入数据：67186a86eb3bb745ece5e85e
# wechat:阿轩
# 插入数据：67186a86eb3bb745ece5e85f
# wechat:
# 开始采集第6页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=6&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a86eb3bb745ece5e860
# wechat:yy
# 插入数据：67186a86eb3bb745ece5e861
# wechat:阿仪
# 插入数据：67186a86eb3bb745ece5e862
# wechat:阳啊阳
# 插入数据：67186a86eb3bb745ece5e863
# wechat:墙头
# 插入数据：67186a87eb3bb745ece5e864
# wechat:花茶子君
# 插入数据：67186a87eb3bb745ece5e865
# wechat:GianniChia
# 插入数据：67186a87eb3bb745ece5e866
# wechat:墙头
# 插入数据：67186a87eb3bb745ece5e867
# wechat:思绪飞扬
# 插入数据：67186a87eb3bb745ece5e868
# wechat:思绪飞扬
# 插入数据：67186a87eb3bb745ece5e869
# wechat:阿白
# 插入数据：67186a87eb3bb745ece5e86a
# wechat:米雅yaya
# 插入数据：67186a87eb3bb745ece5e86b
# wechat:米雅yaya
# 插入数据：67186a87eb3bb745ece5e86c
# wechat:米雅yaya
# 插入数据：67186a87eb3bb745ece5e86d
# wechat:米雅yaya
# 插入数据：67186a87eb3bb745ece5e86e
# wechat:微信用户
# 插入数据：67186a87eb3bb745ece5e86f
# wechat:米雅yaya
# 插入数据：67186a87eb3bb745ece5e870
# wechat:上古天真
# 插入数据：67186a87eb3bb745ece5e871
# wechat:上古天真
# 插入数据：67186a87eb3bb745ece5e872
# wechat:Sound idiot
# 插入数据：67186a87eb3bb745ece5e873
# wechat:君妤
# 开始采集第7页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=7&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a88eb3bb745ece5e874
# wechat:非祁
# 插入数据：67186a88eb3bb745ece5e875
# wechat:非祁
# 插入数据：67186a88eb3bb745ece5e876
# wechat:非祁
# 插入数据：67186a88eb3bb745ece5e877
# wechat:阿钝
# 插入数据：67186a88eb3bb745ece5e878
# wechat:阿钝
# 插入数据：67186a88eb3bb745ece5e879
# wechat:宸汐
# 插入数据：67186a88eb3bb745ece5e87a
# wechat:Hean
# 插入数据：67186a88eb3bb745ece5e87b
# wechat:Hean
# 插入数据：67186a88eb3bb745ece5e87c
# wechat:小沫今天没喝水变成小末
# 插入数据：67186a88eb3bb745ece5e87d
# wechat:米娅
# 插入数据：67186a88eb3bb745ece5e87e
# wechat:太阳呢
# 插入数据：67186a88eb3bb745ece5e87f
# wechat:富贵花
# 插入数据：67186a88eb3bb745ece5e880
# wechat:Mr.Wang
# 插入数据：67186a88eb3bb745ece5e881
# wechat:霍老大
# 插入数据：67186a88eb3bb745ece5e882
# wechat:MIND
# 插入数据：67186a88eb3bb745ece5e883
# wechat:calm
# 插入数据：67186a88eb3bb745ece5e884
# wechat:calm
# 插入数据：67186a88eb3bb745ece5e885
# wechat:Xiaopixiu30
# 插入数据：67186a88eb3bb745ece5e886
# wechat:Xiaopixiu30
# 插入数据：67186a89eb3bb745ece5e887
# wechat:WANI
# 开始采集第8页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=8&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a89eb3bb745ece5e888
# wechat:Xiaopixiu30
# 插入数据：67186a89eb3bb745ece5e889
# wechat:Mr.Wang
# 插入数据：67186a89eb3bb745ece5e88a
# wechat:Mr.Wang
# 插入数据：67186a89eb3bb745ece5e88b
# wechat:M
# 插入数据：67186a89eb3bb745ece5e88c
# wechat:xx
# 插入数据：67186a89eb3bb745ece5e88d
# wechat:介质传媒
# 插入数据：67186a89eb3bb745ece5e88e
# wechat:等等
# 插入数据：67186a89eb3bb745ece5e88f
# wechat:电商设计
# 插入数据：67186a89eb3bb745ece5e890
# wechat:Gabriele
# 插入数据：67186a89eb3bb745ece5e891
# wechat:Gabriele
# 插入数据：67186a89eb3bb745ece5e892
# wechat:Gabriele
# 插入数据：67186a89eb3bb745ece5e893
# wechat:Gabriele
# 插入数据：67186a89eb3bb745ece5e894
# wechat:WANI
# 插入数据：67186a8aeb3bb745ece5e895
# wechat:WANI
# 插入数据：67186a8aeb3bb745ece5e896
# wechat:WANI
# 插入数据：67186a8aeb3bb745ece5e897
# wechat:WANI
# 插入数据：67186a8aeb3bb745ece5e898
# wechat:WANI
# 插入数据：67186a8aeb3bb745ece5e899
# wechat:WANI
# 插入数据：67186a8aeb3bb745ece5e89a
# wechat:WANI
# 插入数据：67186a8aeb3bb745ece5e89b
# wechat:WANI
# 开始采集第9页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=9&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a8aeb3bb745ece5e89c
# wechat:小悦想瘦
# 插入数据：67186a8aeb3bb745ece5e89d
# wechat:微信用户
# 插入数据：67186a8aeb3bb745ece5e89e
# wechat:微信用户
# 插入数据：67186a8aeb3bb745ece5e89f
# wechat:微信用户
# 插入数据：67186a8aeb3bb745ece5e8a0
# wechat:liii
# 插入数据：67186a8aeb3bb745ece5e8a1
# wechat:liii
# 插入数据：67186a8aeb3bb745ece5e8a2
# wechat:liii
# 插入数据：67186a8aeb3bb745ece5e8a3
# wechat:8089
# 插入数据：67186a8beb3bb745ece5e8a4
# wechat:liii
# 插入数据：67186a8beb3bb745ece5e8a5
# wechat:liii
# 插入数据：67186a8beb3bb745ece5e8a6
# wechat:神经蛙
# 插入数据：67186a8beb3bb745ece5e8a7
# wechat:阿仔
# 插入数据：67186a8beb3bb745ece5e8a8
# wechat:尚美
# 插入数据：67186a8beb3bb745ece5e8a9
# wechat:6
# 插入数据：67186a8beb3bb745ece5e8aa
# wechat:晴栀子
# 插入数据：67186a8beb3bb745ece5e8ab
# wechat:王了了
# 插入数据：67186a8beb3bb745ece5e8ac
# wechat:微信用户
# 插入数据：67186a8beb3bb745ece5e8ad
# wechat:微信用户
# 插入数据：67186a8beb3bb745ece5e8ae
# wechat:微信用户
# 插入数据：67186a8beb3bb745ece5e8af
# wechat:湘江
# 开始采集第10页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=10&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a8beb3bb745ece5e8b0
# wechat:苏苏苏苏～
# 插入数据：67186a8ceb3bb745ece5e8b1
# wechat:叶奇奇
# 插入数据：67186a8ceb3bb745ece5e8b2
# wechat:玛希
# 插入数据：67186a8ceb3bb745ece5e8b3
# wechat:Lance Y. Xavier
# 插入数据：67186a8ceb3bb745ece5e8b4
# wechat:超可爱肥嘟嘟左桐桐
# 插入数据：67186a8ceb3bb745ece5e8b5
# wechat:文二
# 插入数据：67186a8ceb3bb745ece5e8b6
# wechat:文二
# 插入数据：67186a8ceb3bb745ece5e8b7
# wechat:文二
# 插入数据：67186a8ceb3bb745ece5e8b8
# wechat:absolut
# 插入数据：67186a8ceb3bb745ece5e8b9
# wechat:饼
# 插入数据：67186a8ceb3bb745ece5e8ba
# wechat:佳(ﾉ_ _)ﾉ
# 插入数据：67186a8ceb3bb745ece5e8bb
# wechat:佳(ﾉ_ _)ﾉ
# 插入数据：67186a8ceb3bb745ece5e8bc
# wechat:全能少女
# 插入数据：67186a8ceb3bb745ece5e8bd
# wechat:Tim
# 插入数据：67186a8ceb3bb745ece5e8be
# wechat:深藏身与名
# 插入数据：67186a8ceb3bb745ece5e8bf
# wechat:深藏身与名
# 插入数据：67186a8ceb3bb745ece5e8c0
# wechat:深藏身与名
# 插入数据：67186a8ceb3bb745ece5e8c1
# wechat:深藏身与名
# 插入数据：67186a8ceb3bb745ece5e8c2
# wechat:yummy
# 插入数据：67186a8deb3bb745ece5e8c3
# wechat:yummy
# 开始采集第11页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=11&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a8deb3bb745ece5e8c4
# wechat:yummy
# 插入数据：67186a8deb3bb745ece5e8c5
# wechat:迷你蚂蚁
# 插入数据：67186a8deb3bb745ece5e8c6
# wechat:迷你蚂蚁
# 插入数据：67186a8deb3bb745ece5e8c7
# wechat:与於戈
# 插入数据：67186a8deb3bb745ece5e8c8
# wechat:与於戈
# 插入数据：67186a8deb3bb745ece5e8c9
# wechat:与於戈
# 插入数据：67186a8deb3bb745ece5e8ca
# wechat:与於戈
# 插入数据：67186a8deb3bb745ece5e8cb
# wechat:橘子丷
# 插入数据：67186a8deb3bb745ece5e8cc
# wechat:快乐脸苒
# 插入数据：67186a8deb3bb745ece5e8cd
# wechat:1
# 插入数据：67186a8deb3bb745ece5e8ce
# wechat:1
# 插入数据：67186a8eeb3bb745ece5e8cf
# wechat:阿白
# 插入数据：67186a8eeb3bb745ece5e8d0
# wechat:1
# 插入数据：67186a8eeb3bb745ece5e8d1
# wechat:阿  武
# 插入数据：67186a8eeb3bb745ece5e8d2
# wechat:和五安黄
# 插入数据：67186a8eeb3bb745ece5e8d3
# wechat:南妮
# 插入数据：67186a8eeb3bb745ece5e8d4
# wechat:Pink
# 插入数据：67186a8eeb3bb745ece5e8d5
# wechat:付与东流
# 插入数据：67186a8eeb3bb745ece5e8d6
# wechat:漠然
# 插入数据：67186a8eeb3bb745ece5e8d7
# wechat:漠然
# 开始采集第12页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=12&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a8eeb3bb745ece5e8d8
# wechat:漠然
# 插入数据：67186a8eeb3bb745ece5e8d9
# wechat:漠然
# 插入数据：67186a8eeb3bb745ece5e8da
# wechat:漠然
# 插入数据：67186a8eeb3bb745ece5e8db
# wechat:愫语
# 插入数据：67186a8eeb3bb745ece5e8dc
# wechat:N
# 插入数据：67186a8eeb3bb745ece5e8dd
# wechat:N
# 插入数据：67186a8feb3bb745ece5e8de
# wechat:小倩
# 插入数据：67186a8feb3bb745ece5e8df
# wechat:小宋honey
# 插入数据：67186a8feb3bb745ece5e8e0
# wechat:金泡菜真好吃
# 插入数据：67186a8feb3bb745ece5e8e1
# wechat:张蕊Z.R
# 插入数据：67186a8feb3bb745ece5e8e2
# wechat:金泡菜真好吃
# 插入数据：67186a8feb3bb745ece5e8e3
# wechat:金泡菜真好吃
# 插入数据：67186a8feb3bb745ece5e8e4
# wechat:金泡菜真好吃
# 插入数据：67186a8feb3bb745ece5e8e5
# wechat:微信用户
# 插入数据：67186a8feb3bb745ece5e8e6
# wechat:林间有新绿
# 插入数据：67186a8feb3bb745ece5e8e7
# wechat:Jolie
# 插入数据：67186a8feb3bb745ece5e8e8
# wechat:Jolie
# 插入数据：67186a8feb3bb745ece5e8e9
# wechat:No.wansyn
# 插入数据：67186a8feb3bb745ece5e8ea
# wechat:No.wansyn
# 插入数据：67186a8feb3bb745ece5e8eb
# wechat:Cici
# 开始采集第13页:https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-10-23+11:15:59&addStartTime=2024-09-24+11:15:59&admin_id=0&is_five_star=&page=13&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=
# 插入数据：67186a90eb3bb745ece5e8ec
# wechat:桩
# 插入数据：67186a90eb3bb745ece5e8ed
# wechat:Hachiman
# 插入数据：67186a90eb3bb745ece5e8ee
# wechat:Hachiman
# 插入数据：67186a90eb3bb745ece5e8ef
# wechat:Eunice
# 插入数据：67186a90eb3bb745ece5e8f0
# wechat:南妮
# 插入数据：67186a90eb3bb745ece5e8f1
# wechat:桃圆圆
# 插入数据：67186a90eb3bb745ece5e8f2
# wechat:唯不安者得安宁
# 插入数据：67186a90eb3bb745ece5e8f3
# wechat:Monke
# 插入数据：67186a90eb3bb745ece5e8f4
# wechat:Monke
# 插入数据：67186a90eb3bb745ece5e8f5
# wechat:Monke
# 数据存在
