# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from requests_html import HTMLSession

session = HTMLSession()
uri = "mongodb+srv://hhnnww:12qwaszx@tibetunit.fdr8m8w.mongodb.net/?retryWrites=true&w=majority&appName=tibetunit"
client = MongoClient(uri, server_api=ServerApi("1"))
database = client["电商宝返款订单"]
col_order = database["订单列表"]
col_page = database["所有页面"]

col_page.create_index(keys="page", unique=True)
col_order.create_index(keys="order_sn", unique=True)
# Out:
# 'order_sn_1'

# %%
col_page.drop()
all_url = []
for x in range(36273, 0, -1):
    new_url = f"https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-12-13+19:18:00&addStartTime=2005-11-01+19:18:00&admin_id=0&is_five_star=&page={x}&shop_id=0&status=0&wechatAuthId=15183&wechat_nick="
    all_url.append({"page": new_url, "state": False, "num": x})
col_page.insert_many(all_url)
# Out:
# InsertManyResult([ObjectId('675d69c1d42b54239566da30'), ObjectId('675d69c1d42b54239566da31'), ObjectId('675d69c1d42b54239566da32'), ObjectId('675d69c1d42b54239566da33'), ObjectId('675d69c1d42b54239566da34'), ObjectId('675d69c1d42b54239566da35'), ObjectId('675d69c1d42b54239566da36'), ObjectId('675d69c1d42b54239566da37'), ObjectId('675d69c1d42b54239566da38'), ObjectId('675d69c1d42b54239566da39'), ObjectId('675d69c1d42b54239566da3a'), ObjectId('675d69c1d42b54239566da3b'), ObjectId('675d69c1d42b54239566da3c'), ObjectId('675d69c1d42b54239566da3d'), ObjectId('675d69c1d42b54239566da3e'), ObjectId('675d69c1d42b54239566da3f'), ObjectId('675d69c1d42b54239566da40'), ObjectId('675d69c1d42b54239566da41'), ObjectId('675d69c1d42b54239566da42'), ObjectId('675d69c1d42b54239566da43'), ObjectId('675d69c1d42b54239566da44'), ObjectId('675d69c1d42b54239566da45'), ObjectId('675d69c1d42b54239566da46'), ObjectId('675d69c1d42b54239566da47'), ObjectId('675d69c1d42b54239566da48'), ObjectId('675d69c1d42b54239566
# ...

# %%
for page in col_page.find({"state": True}).sort(key_or_list={"num": -1}):
    print(page)
    col_page.update_one(
        filter={"_id": page.get("_id")}, update={"$set": {"state": False}}
    )
    break
# Out:
# {'_id': ObjectId('675d3ae3d42b542395664c72'), 'page': 'https://appscrm.ecbao.cn/api/evaluateRebate/detail.json?addEndTime=2024-12-14+13:46:48&addStartTime=2005-01-01+13:46:00&admin_id=0&is_five_star=&page=36286&shop_id=0&status=0&wechatAuthId=15183&wechat_nick=', 'state': True, 'num': 36286}

# %%
req_header = """POST /api/evaluateRebate/detail.json?addEndTime=2024-12-13+19:09:00&addStartTime=2004-11-01+19:09:00&admin_id=0&is_five_star=&page=1&shop_id=0&status=0&wechatAuthId=15183&wechat_nick= HTTP/1.1
Accept: application/json, text/plain, */*
Accept-Encoding: gzip, deflate, br, zstd
Accept-Language: zh-CN,zh;q=0.9
Connection: keep-alive
Content-Length: 0
