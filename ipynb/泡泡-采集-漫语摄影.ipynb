# %%
from selenium.webdriver import Edge, EdgeOptions
from selenium.webdriver.common.by import By

options = EdgeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-gpu")
options.add_argument("--remote-debugging-port=9222")
options.add_argument("--single-process")

driver = Edge(options=options)
driver.implicitly_wait(50)
driver.set_window_rect(x=1274, y=0, width=1292, height=1398)
# Out:
# The msedgedriver version (128.0.2739.67) detected in PATH at C:\Program Files\edgedriver_win64\msedgedriver.exe might not be compatible with the detected MicrosoftEdge version (129.0.2792.89); currently, msedgedriver 129.0.2792.89 is recommended for MicrosoftEdge 129.*, so it is advised to delete the driver in PATH and retry
# {'height': 1398, 'width': 1292, 'x': 1274, 'y': 0}

# %%
driver.get(
    "https://shop293231589.taobao.com/?spm=pc_detail.29232929/evo365560b447259.shop_block.dentershop.4be37dd60Hagnf"
)

# %%
import time

from selenium.webdriver.common.keys import Keys

for x in range(50):
    driver.find_element(by=By.CSS_SELECTOR, value="body").send_keys(Keys.PAGE_DOWN)
    time.sleep(2)

objs = driver.find_elements(
    by=By.CSS_SELECTOR,
    value="#ice-container > div > div > div.flexCell--O42zbLr4 > div.shopProductShelfArea--Z6GzvxkU > div > div:nth-child(3) > div > div",
)
print(len(objs))
# Out:
# 422

# %%
from MaterialEdit.fun_素材下载.fun_插入素材 import fun_插入素材
from MaterialEdit.fun_素材下载.model_素材格式 import MaterialModel

for obj in objs:
    url = obj.find_element(By.CSS_SELECTOR, "a").get_dom_attribute("href")
    img = obj.find_element(By.CSS_SELECTOR, "img").get_dom_attribute("src")
    print(url, img)

    mod = MaterialModel(url=url, img=img, state=False)
    fun_插入素材(shop_name="泡泡素材", material_site="漫语摄影", material_model=mod)
# Out:
# https://item.taobao.com/item.htm?spm=a21xtw.29178619.product_shelf.1.7a623d6ea7fxBz&id=736425244499&pisk=gvVEFhD1s6CUDKCj5VhruGW4aLlKZXjf87iSrz4oRDmnA7Zzr4uet4mnKCYiRcO5JX6-auoa2DMIt7y9arU8Owh5JXUKwbjfcsOzJyhR-hPzYWRgSqUMZQvhG-FauAjfcs1y_OImiiZIU4ESjqumZ2DoZhbZrqioZ2Dh7c0rkLx3qbbN74g2qH0oxP0iPqGkxD0oSA0jPQAoqpfG74niqb0aqkdZbvbXD1dhfGBxKm4nbQA2k2kh4yJWNQw--vPu-c7155uELmktWtOTtlauOWHOIdl85-rzEuBXBXzuKX0bJ6RZiy2_aVN5PLo3v5zgsA8XGolU4xVnQUA7uboK_VVcPKn__DZuTAbXgYGgGxc3COIIFXu4qWEezQq05rNKB7S2j0eIkf0bJ6RZiy0l4gt-SqC_wJ-kUv0t7m_N7U1bzv3_R9ykeLHNBVofkZpJev0t7m_UwLp-QWuZcwbc. https://gw.alicdn.com/imgextra/O1CN01QEvdfm1qin7KPEUHq_!!2212625795530.jpg_q95.jpg_.webp
# 素材已经存在
# https://item.taobao.com/item.htm?id=736918622237 https://gw.alicdn.com/imgextra/O1CN01mTSvut1qin7DBtxkp_!!2212625795530.jpg_q95.jpg_.webp
# 插入到数据库：671258b880cf7ecb9dc3efec
# https://item.taobao.com/item.htm?id=740822794205 https://gw.alicdn.com/imgextra/O1CN01FTPZlD1qin7foFBFl_!!2212625795530.jpg_q95.jpg_.webp
# ...
