# %%
import re

import pyperclip
from requests_html import HTML

from MaterialEdit.fun_素材下载.fun_插入素材 import fun_插入素材
from MaterialEdit.fun_素材下载.model_素材格式 import MaterialModel

text = pyperclip.paste()

text = """


jsonp530("<!--    useCSI: true   asynSearch : $asynSearch  closeSearchTmallAsyn : $closeSearchTmallAsyn  --><!--  loginUserId : 2218686144077 sgSessionRisk: $sgSessionRisk isFy2024SecGray : true  mappingCode :b09e4efa-5fb8-4a70-9a3e-fa557bb9bbf0-AlibabaSans102 --><!-- false  --><!-- $categoryId $aabc 搜索列表${x-shop-url}请求:searchURL: http://admin.search.taobao.com/proxyjump/go?url=http%3A%2F%2F33.90.109.153%3A80%2Fbin%2Fsp%3Fsrc%3Dshopsystem--33.53.242.67%26sort%3Dfirst_new%3Ades%26tab%3Dall%26ss_bucket%3D2%26rank_src%3Dinshop_pc_tb%26buyernick%3Dtb590251230413%26shop_id%3D585126941%26navigator%3Dproperty%26shopproductcount%3D1361%26sellerid%3D1941722960%26sessionid%3Dshopsystem-616442992%26s%3D144%26n%3D24%26app%3Dinshop%26outfmt%3Djson%26token%3D9e2f5b94，无宝贝：searchURL: , bucketId: 2 bucketUser：tb590251230413 --><style type=\"text/css\">    .item {        overflow: unset !important;    }    .c-app-tips > .c-app-img {        display: none;    }    .c-app-tips:hover > .c-app-img {        display: block;        padding: 6px;        position: absolute;        top: 16px;        right: 10px;        z-index: 10000;        text-align: center;        border-radius: 9px;        background: #ffffff;        width: 100px;        box-shadow: 0 9px 18px 0 rgba(0, 0, 0, 0.06);    }    .item > dd.detail {        overflow: unset !important;    }</style>            <!--  rsdata.trackidStr : aacb8e3a39796fd066f1dc1516c95669 rsdata.cnaStr : CkaVH6j9KiECARsRu/9nQ3xp rsdata.showSaleData:     --><!-- $categoryId  搜索列表${x-shop-url}请求:searchURL: http://admin.search.taobao.com/proxyjump/go?url=http%3A%2F%2F33.90.109.153%3A80%2Fbin%2Fsp%3Fsrc%3Dshopsystem33.53.242.67%26sort%3Dfirst_new%3Ades%26tab%3Dall%26ss_bucket%3D2%26rank_src%3Dinshop_pc_tb%26buyernick%3Dtb590251230413%26shop_id%3D585126941%26navigator%3Dproperty%26shopproductcount%3D1361%26sellerid%3D1941722960%26sessionid%3Dshopsystem-616442992%26s%3D144%26n%3D24%26app%3Dinshop%26outfmt%3Djson%26token%3D9e2f5b94，无宝贝：searchURL: , bucketId: 2 bucketUser：tb590251230413 -->        <img height=\"0\" width=\"0\" alt=\"\" style=\"display: none;\"         src=\"//gm.mmstat.com/inshopse?logtype=2&gokey=at_bucketid%3D%26srppage%3D7%26scid%3D%26lf_aclog%3D0-0-24-newOn_desc-1941722960%26%3Fsrc%3Dshopsystem--33.53.242.67%26sort%3Dfirst_new%3Ades%26tab%3Dall%26ss_bucket%3D2%26rank_src%3Dinshop_pc_tb%26buyernick%3Dtb590251230413%26shop_id%3D585126941%26navigator%3Dproperty%26shopproductcount%3D1361%26sellerid%3D1941722960%26sessionid%3Dshopsystem-616442992%26s%3D144%26n%3D24%26app%3Dinshop%26outfmt%3Djson%26token%3D9e2f5b94%26stats_click%3D%26rn%3De9219f9119b0b959ad0656c017c94381%26is_pv%3D1%26found_num%3D24%26item_list%3D824890145036%2C825004180121%2C824632882434%2C824403086405%2C824569013367%2C824682312545%2C824638184261%2C823936259655%2C824254565669%2C823853815301%2C823962230062%2C823697293781%2C823471694143%2C823274943117%2C823409090640%2C823413009081%2C823178498510%2C823468516874%2C822939658970%2C822740295895%2C823111093111%2C823146008012%2C822638163479%2C822605574796%2C&rn=650dd52e6748d61e7bb90a02fd206dd7&bc_type=c&cna=CkaVH6j9KiECARsRu/9nQ3xp\"/>                    <input type=\"hidden\" class=\"J_TItemRatesUrl\"               value=\"//rate.taobao.com/batch_query_rate.htm?sellerId=1941722960&itemIds=824890145036,825004180121,824632882434,824403086405,824569013367,824682312545,824638184261,823936259655,824254565669,823853815301,823962230062,823697293781,823471694143,823274943117,823409090640,823413009081,823178498510,823468516874,822939658970,822740295895,823111093111,823146008012,822638163479,822605574796&source=shop\"/>                            <div class=\"skin-box-bd\">                <span data-info=\"\" id=\"J_ShopSearchUserParams\"></span>                <span data-info=\"keyword=&price1=&price2=&bannerPageTitle=搜索宝贝\" id=\"J_UserSearchParams\"></span>                <div class=\"shop-hesper-hd J_TWidget\"                     data-widget-config=\"{'triggerCls': 'trigger', 'panelCls': 'hesper-content','multiple': 'true', 'activeTriggerCls': 'collapse'}\"                     data-widget-type=\"Accordion\">                    <div id=\"J_HesperCats\" class=\"hesper-cats\">                        <ol>                            <li>                                <a href=\"//shop585126941.taobao.com/search.htm?search=y\" class=\"J_SearchAsync\">所有宝贝</a><i                                    class=\"right-arrow\"></i>                            </li>                                                    </ol>                        <div class=\"hesper-content\">                                                            <div class=\"J_PropSingle attr-data\">                                                                        <table class=\"J_AttrBox\">                                        <tbody>                                                                                    </tbody>                                    </table>                                                                    </div><!-- END OF J_PropSingle attr-data结束具体的属性显示-->                                                    </div><!--END OF hesper-content-->                        <i title=\"展开或者收缩\" class=\"trigger\" id=\"J_HesperCatsTrigger\"></i>                    </div><!--END OF hesper-cats-->                    <form method=\"get\" id=\"shop-search-list\" accept-charset=\"gbk\"                          action=\"//shop585126941.taobao.com/search.htm?input_charset=gbk\">                        <div class=\"shop-search\">                            <div class=\"search-form\" style=\"width:517px;\">                                <ul>                                    <input type=\"hidden\" data-info=\"//shop585126941.taobao.com/search.htm?search=y&input_charset=gbk\"                                           id=\"J_ShopSearchFormUrl\">                                    <input type=\"hidden\" value=\"newOn_desc\" name=\"orderType\">                                    <input type=\"hidden\" value=\"grid\" name=\"viewType\">                                                                                                                                                                                    <li class=\"keyword\">                                        <label for=\"keyword\">关键字：</label>                                        <input type=\"text\" value=\"\" name=\"keyword\">                                    </li>                                    <li class=\"price\">                                        <label for=\"price\">价格：</label>                                        <input type=\"text\" value=\"\"                                               class=\"price J_CheckInput\" name=\"lowPrice\" id=\"price1\">                                        到                                        <input type=\"text\" value=\"\"                                               class=\"price J_CheckInput\" name=\"highPrice\" id=\"price2\">                                    </li>                                    <li class=\"submit\">                                        <button class=\"button\" type=\"submit\">搜索</button>                                    </li>                                </ul>                            </div>                            <div class=\"search-result\">                                共搜索到<span> 1361 </span>个符合条件的商品。                            </div>                        </div>                    </form>                </div><!--END OF shop-hesper-hd J_TWidget结束属性导航div的显示-->                <div class=\"shop-hesper-bd grid\">                    <div class=\"shop-filter\">                        <div class=\"mode\">                            <span>显示：</span>                            <a class=\"J_SearchAsync mode-row\" title=\"列表方式\" alt=\"列表方式\"                               href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&amp;pageNo=7&viewType=list\">列表模式</a>                            <a class=\"J_SearchAsync mode-grid\" title=\"图表方式\" alt=\"图表方式\"                               href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&amp;pageNo=7&viewType=grid\">图表模式</a>                        </div>                        <div class=\"taxis\">                            <span>排序：</span>                                                        <a title=\"按人气排列\" alt=\"按人气排列\" class=\" J_SearchAsync down \"                               href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;pageNo=7&orderType=coefp_desc&bucket_id=2\">人气<i                                    class=\"order-icon down-icon\"></i></a>                                                        <a class=\" J_SearchAsync down \"                               title=\"按销量排列\" alt=\"按销量排列\"                               href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;pageNo=7&orderType=hotsell_desc\">销量<i                                    class=\"order-icon down-icon\"></i></a>                                                        <a class=\"selected\"                               title=\"按新品排列\" alt=\"按新品排列\"                               href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;pageNo=7&orderType=newOn_desc\">新品<i                                    class=\"order-icon down-icon\"></i></a>                                                        <a class=\" J_SearchAsync def\"                               title=\"按价格排列\" alt=\"按价格排列\"                               href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;pageNo=7&orderType=price_asc\">价格<i                                    class=\"order-icon up-icon\"></i></a>                                                        <a class=\" J_SearchAsync fav def\"                               title=\"按收藏排列\" alt=\"按收藏排列\"                               href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;pageNo=7&orderType=hotkeep_desc\">收藏<i                                    class=\"order-icon down-icon\"></i></a>                        </div>                        <div class=\"pagination pagination-mini\">                            <span class=\"page-info\">7/57</span>                                                                                                                                                                            <a                                    href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=6\"   >上一页</a>                                <a                                                                       href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=8\"  >下一页</a>                                                    </div>                    </div>                                                                                                                                                                                <div class=\"item4line1\">                                                                                    <dl class=\"item \"                                data-id=\"824890145036\">                                <dt class=\"photo\">                                    <a class=\"J_TGoldData\" href=\"//item.taobao.com/item.htm?id=824890145036\" target=\"_blank\" data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=1-824890145036-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                                                                    <img                                                                         src=\"//img.alicdn.com/bao/uploaded/i4/1941722960/O1CN01h7lIll1XjjKscD8j0_!!1941722960.jpg_180x180.jpg\"  >                                                                            </a>                                </dt>                                <dd class=\"detail\">                                    <a class=\"item-name J_TGoldData\" href=\"//item.taobao.com/item.htm?id=824890145036\" target=\"_blank\"                                       data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=1-824890145036-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                        景观造型植物灌木球造型树psd素材 迎客罗汉松桩景效果图棒棒糖PS</a>                                    <div class=\"attribute\">                                                                                                                                                                                                            <div class=\"cprice-area\">                                                <span class=\"symbol\">&yen;</span>                                                                                                    <span class=\"c-price\"                                                          style=\"font-family: AlibabaSans102CustomFont;\">&#25086;&#23194;&#20894;&#23773;</span>                                                                                            </div>                                                                                <!--rsdata.showSaleData: -->                                                                            </div>                                                                    </dd>                            </dl>                                                                                                                                                                                                                            <dl class=\"item \"                                data-id=\"825004180121\">                                <dt class=\"photo\">                                    <a class=\"J_TGoldData\" href=\"//item.taobao.com/item.htm?id=825004180121\" target=\"_blank\" data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=2-825004180121-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                                                                    <img                                                                         src=\"//img.alicdn.com/bao/uploaded/i3/1941722960/O1CN01N5ebHp1XjjKtQ1CF0_!!1941722960.jpg_180x180.jpg\"  >                                                                            </a>                                </dt>                                <dd class=\"detail\">                                    <a class=\"item-name J_TGoldData\" href=\"//item.taobao.com/item.htm?id=825004180121\" target=\"_blank\"                                       data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=2-825004180121-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                        景观座椅树池坐凳ps素材 户外休闲公共公园小区PSD免扣效果图后期</a>                                    <div class=\"attribute\">                                                                                                                                                                    <div class=\"cprice-area\">                                                <span class=\"symbol\">&yen;</span>                                                                                                    <span class=\"c-price\"                                                          style=\"font-family: AlibabaSans102CustomFont;\">&#22641;&#29317;&#21364;&#27813;</span>                                                    <!-- transFormedDiscntPrice -->                                                                                            </div>                                            <div class=\"sprice-area\">                                                <span class=\"symbol\">&yen;</span>                                                                                                    <span class=\"s-price\"                                                          style=\"font-family: AlibabaSans102CustomFont;\">&#25086;&#23194;&#20894;&#23773;</span>                                                                                            </div>                                                                                <!--rsdata.showSaleData: -->                                                                            </div>                                                                    </dd>                            </dl>                                                                                                                                                                                                                            <dl class=\"item \"                                data-id=\"824632882434\">                                <dt class=\"photo\">                                    <a class=\"J_TGoldData\" href=\"//item.taobao.com/item.htm?id=824632882434\" target=\"_blank\" data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=3-824632882434-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                                                                    <img                                                                         src=\"//img.alicdn.com/bao/uploaded/i1/1941722960/O1CN01I6w2AR1XjjKqa7GAI_!!1941722960.jpg_180x180.jpg\"  >                                                                            </a>                                </dt>                                <dd class=\"detail\">                                    <a class=\"item-name J_TGoldData\" href=\"//item.taobao.com/item.htm?id=824632882434\" target=\"_blank\"                                       data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=3-824632882434-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                        新农村环境景观改造效果图ps后期 美丽乡村绿化花境卉素材psd分层</a>                                    <div class=\"attribute\">                                                                                                                                                                                                            <div class=\"cprice-area\">                                                <span class=\"symbol\">&yen;</span>                                                                                                    <span class=\"c-price\"                                                          style=\"font-family: AlibabaSans102CustomFont;\">&#25086;&#23194;&#20894;&#23773;</span>                                                                                            </div>                                                                                <!--rsdata.showSaleData: -->                                                                            </div>                                                                    </dd>                            </dl>                                                                                                                                                                                                                            <dl class=\"item last\"                                data-id=\"824403086405\">                                <dt class=\"photo\">                                    <a class=\"J_TGoldData\" href=\"//item.taobao.com/item.htm?id=824403086405\" target=\"_blank\" data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=4-824403086405-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                                                                    <img                                                                         src=\"//img.alicdn.com/bao/uploaded/i1/1941722960/O1CN017FM67V1XjjKrU8CcN_!!1941722960.jpg_180x180.jpg\"  >                                                                            </a>                                </dt>                                <dd class=\"detail\">                                    <a class=\"item-name J_TGoldData\" href=\"//item.taobao.com/item.htm?id=
price\"                                                          style=\"font-family: AlibabaSans102CustomFont;\">&#25086;&#23194;&#20894;&#23773;</span>                                                                                            </div>                                                                                <!--rsdata.showSaleData: -->                                                                            </div>                                                                    </dd>                            </dl>                                                                                                                                                                                                                            <dl class=\"item last\"                                data-id=\"822605574796\">                                <dt class=\"photo\">                                    <a class=\"J_TGoldData\" href=\"//item.taobao.com/item.htm?id=822605574796\" target=\"_blank\" data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=24-822605574796-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                                                                    <img                                                                         src=\"//img.alicdn.com/bao/uploaded/i3/1941722960/O1CN01r3DsMU1XjjKj8bSFV_!!1941722960.jpg_180x180.jpg\"  >                                                                            </a>                                </dt>                                <dd class=\"detail\">                                    <a class=\"item-name J_TGoldData\" href=\"//item.taobao.com/item.htm?id=822605574796\" target=\"_blank\"                                       data-gold-url=\"/inshopse\"                                       data-gold-data='{\"gokey\":\"at_bucketid=&amp;srppage=7&amp;scid=&amp;lf_aclog=24-822605574796-24-newOn_desc-1941722960&amp;?src=shopsystem--33.53.242.67&amp;sort=first_new:des&amp;tab=all&amp;ss_bucket=2&amp;rank_src=inshop_pc_tb&amp;buyernick=tb590251230413&amp;shop_id=585126941&amp;navigator=property&amp;shopproductcount=1361&amp;sellerid=1941722960&amp;sessionid=shopsystem-616442992&amp;s=144&amp;n=24&amp;app=inshop&amp;outfmt=json&amp;token=9e2f5b94&amp;stats_click=&amp;rn=e9219f9119b0b959ad0656c017c94381\", \"cna\": \"CkaVH6j9KiECARsRu/9nQ3xp\",\"bc_type\":\"c\" }'>                                        弥散光影光落日灯光暖光氛围直播间虚拟绿幕室内JPG背景图片素材</a>                                    <div class=\"attribute\">                                                                                                                                                                    <div class=\"cprice-area\">                                                <span class=\"symbol\">&yen;</span>                                                                                                    <span class=\"c-price\"                                                          style=\"font-family: AlibabaSans102CustomFont;\">&#22641;&#29317;&#21364;&#27813;</span>                                                    <!-- transFormedDiscntPrice -->                                                                                            </div>                                            <div class=\"sprice-area\">                                                <span class=\"symbol\">&yen;</span>                                                                                                    <span class=\"s-price\"                                                          style=\"font-family: AlibabaSans102CustomFont;\">&#25086;&#23194;&#20894;&#23773;</span>                                                                                            </div>                                                                                <!--rsdata.showSaleData: -->                                                                            </div>                                                                    </dd>                            </dl>                                                        </div>                                                                                                                                                                            <div class=\"pagination\">                                                                                                <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                    <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=6#anchor\">上一页</a>                                                                                                                                                                                                    <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=1#anchor\">1</a>                                                                                                                                                                                                            <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=2#anchor\">2</a>                                                                                                                                                                    <span class=\"break\">...</span>                                                                                                                                                                        <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=5#anchor\">5</a>                                                                                                                                                                                                            <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=6#anchor\">6</a>                                                                                                                                                                    <a class=\"page-cur\">7</a>                                                                                                                                                                        <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=8#anchor\">8</a>                                                                                                                                                                                                            <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=9#anchor\">9</a>                                                                                                                                                                                                            <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=10#anchor\">10</a>                                                                                                                                                                                                            <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                        <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=11#anchor\">11</a>                                                                                                                                                                    <span class=\"break\">...</span>                                                                                                                                                            <!-- 当前用户已登录 或者 未被灰度到，允许翻页  -->                                    <a class=\"J_SearchAsync next\" href=\"//shop585126941.taobao.com/search.htm?_ksTS=1729045906962_529&amp;callback=jsonp530&amp;input_charset=gbk&amp;mid=w-21648212623-0&amp;wid=21648212623&amp;path=%2Fsearch.htm&amp;search=y&amp;spm=a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53&amp;orderType=newOn_desc&pageNo=8#anchor\">下一页</a>                                                                                                                        <form action=\"//shop585126941.taobao.com/search.htm\" method=\"get\">                                                                                                                        <input type=\"hidden\" name=\"_ksTS\" value=\"1729045906962_529\">                                                                                                                                                                <input type=\"hidden\" name=\"callback\" value=\"jsonp530\">                                                                                                                                                                <input type=\"hidden\" name=\"input_charset\" value=\"gbk\">                                                                                                                                                                <input type=\"hidden\" name=\"mid\" value=\"w-21648212623-0\">                                                                                                                                                                <input type=\"hidden\" name=\"wid\" value=\"21648212623\">                                                                                                                                                                <input type=\"hidden\" name=\"path\" value=\"%2Fsearch.htm\">                                                                                                                                                                <input type=\"hidden\" name=\"search\" value=\"y\">                                                                                                                                                                <input type=\"hidden\" name=\"spm\" value=\"a1z10.3-c.w4002-21648212623.10.1f7b3576AJck53\">                                                                                                                                                                <input type=\"hidden\" name=\"orderType\" value=\"newOn_desc\">                                                                                                                                                                                            到第 <input type=\"text\" value=\"7\" size=\"3\" name=\"pageNo\"> 页                                    <button type=\"submit\">确定</button>                                </form>                                                        <!--END OF  pagination-->                        </div>                                    </div>            </div>                ")

"""

html_text = re.findall(r"\<div[\s\S]*<\/div>", text)[0]

print(html_text)

html = HTML(html=html_text)
for obj in html.find("dt.photo"):
    href = list(obj.find("a", first=True).absolute_links)[0]
    print(href)

    img = "https:" + obj.find("img", first=True).attrs.get("src").replace(
        "_180x180.jpg", ""
    )
    print(img)

    mod = MaterialModel(url=href, img=img, state=False)
    fun_插入素材(shop_name="吉克丝", material_site="NEW模型", material_model=mod)
# Out:
# <div class="skin-box-bd">                <span data-info="" id="J_ShopSearchUserParams"></span>                <span data-info="keyword=&price1=&price2=&bannerPageTitle=搜索宝贝" id="J_UserSearchParams"></span>                <div class="shop-hesper-hd J_TWidget"                     data-widget-config="{'triggerCls': 'trigger', 'panelCls': 'hesper-content','multiple': 'true', 'activeTriggerCls': 'collapse'}"                     data-widget-type="Accordion">                    <div id="J_HesperCats" class="hesper-cats">                        <ol>                            <li>                                <a href="//shop585126941.taobao.com/search.htm?search=y" class="J_SearchAsync">所有宝贝</a><i                                    class="right-arrow"></i>                            </li>                                                    </ol>                        <div class="hesper-content">                                                            <div class="J_PropSingle attr-data"
# ...
